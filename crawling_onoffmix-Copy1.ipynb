# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import requests
import os

#os.chdir('/Users/hj/dev/meetup_crawl')
#os.getcwd()
print(os.getcwd() + '/enviroments/chromedriver')
# Out:
# /Users/hj/dev/meetup_crawl/enviroments/chromedriver

# %%
driver = webdriver.Chrome(os.getcwd() + '/enviroments/chromedriver') #드라이버 경로지정

# %%
driver.implicitly_wait(3)#웹 자원 로드를 위해 3초까지 기다림.

# %% [markdown]
# # 구글 드라이버 실행

# %%
driver.get('https://www.onoffmix.com/account/login') #get 로그인 페이지

# %%
#로그인
driver.find_element_by_class_name('email').send_keys('kimzombie@hotmail.com')
driver.find_element_by_class_name('password').send_keys('asdf65851242!@')

driver.find_element_by_class_name('btn_submit').click()

#로그인 완료될때까지 기다리는 구문 필요

# %% [markdown]
# # <로그인 완료>

# %%
#baseURL
base_URL = 'https://www.onoffmix.com' #온오프믹스
#get 교육 페이지
list_URL = base_URL + '/event/main/?c=085' #모임 리스트
driver.get(list_URL)

#최근순으로 이동
recent_selector = '#content > div > section.event_main_area > div.title_bar > ul.sort_menu > li:nth-child(2) > a'
driver.find_element_by_css_selector(recent_selector).click()

#페이지이동
#driver.find.element_by_

# %%
#content > div > section.event_main_area > div.pagination_wrap > div > a:nth-child(3)
#content > div > section.event_main_area > div.pagination_wrap > div > a:nth-child(4)

#content > div > section.event_main_area > div.pagination_wrap > div > a:nth-child(3)
#content > div > section.event_main_area > div.pagination_wrap > div > a:nth-child(4)

#content > div > section.event_main_area > div.pagination_wrap > div > a.btn_prev
#content > div > section.event_main_area > div.pagination_wrap > div > a.page_move.active.disabled
#content > div > section.event_main_area > div.pagination_wrap > div > a:nth-child(3)

# %%
html = driver.page_source
list_soup = BeautifulSoup(html, 'html.parser')
list_selector = '#content > div > section.event_main_area > ul > li > article > a'
selected = list_soup.select(list_selector)
selected
# Out:
# [<a href="/cs/a/44280?url=%2Fevent%2F181448" target="_blank">
#  <!-- 이미지 -->
#  <div class="event_thumbnail">
#  <div class="end_layer">
#  <p class="end_txt">종료된 모임입니다</p>
#  </div>
#  <img alt="아마존과 함께하는 스타트업 글로벌 진출 세미나" src="https://cfile1.onoffmix.com/images/event/181448/s"/>
#  </div>
#  <div class="event_info_area">
#  <!-- 타이틀 -->
#  <div class="title_area">
#  <h5 class="title ellipsis" title="아마존과 함께하는 스타트업 글로벌 진출 세미나">(AD) 아마존과 함께하는 스타트업 글로벌 진출 세미나</h5>
#  <!-- 심플 라인일때만 보여짐 -->
#  <!-- <h6 class="sub_title">서브 타이틀입니다</h6> -->
#  </div>
#  <!-- 정보 -->
#  <div class="event_info">
#  <div class="type_info">
#  <span class="payment_type free">무료</span>
#  <span class="category_type">세미나/컨퍼런스</span>
#  </div>
#  <div class="date">6.21</div>
#  </div>
#  <!-- 태그 => 리스트 형식일때 보여짐. : 추가된 항목  -->
#  <div class="list_event_tags">
#  </div>
#  </div>
#  <!-- list_  리스트 형식일때 보여짐. : 추가된 항목 -->
#  <div class="list_date_place">
#  <div class="wrapping">
#  <span class="date">2019.6.21 (금) 15:00 ~ 17:00</span>
#  <span class="place">서울 중구</span>
#  </div>
#  </div>
#  <!-- ONOFFMIX-3408 모임보기가 리스트 형일때만 보여짐 : 구조변경됨 확인바람 -->
#  <div class="event_state_area">
#  <span class="wrapping">
#  <span class="available"><strong>104</strong>명 신청가능</span>
#  <!-- 추가된 항목 -->
#  <span class="before_closing">마감 <strong class="day">2주전</strong></span>
#  </span>
#  </div>
#  </a>, <a href="/event/182109" target="_blank">
#  <!-- 이미지 -->
#  <div class="event_thumbnail">
#  <div class="end_layer">
#  <p class="end_txt">종료된 모임입니다</p>
#  </div>
#  <img alt="스파크 러닝 퍼실리테이션" src="https://cfile1.onoffmix.com/images/event/182109/s"/>
#  </div>
#  <div class="event_info_area">
#  <!-- 타이틀 -->
#  <div class="title_area">
#  <h5 class="title ellipsis" title="스파크 러닝 퍼실리테이션">스파크 러닝 퍼실리테이션</h5>
#  <!-- 심플 라인일때만 보여짐 -->
#  <!-- <h6 class='sub_title'>서브 타이틀입니다</h6> -->
#  </div>
#  <!-- 정보 -->
#  <div class="event_info">
#  <div class="type_info">
#  <span class="payment_type pay">유료</span>
#  <span class="category_type">교육</span>
#  </div>
#  <div class="date">6.8 ~ 6.9</div>
#  </div>
#  <!-- 태그 => 리스트 형식일때 보여짐. : 추가된 항목  -->
#  <div class="list_event_tags">
#  <span class="tag" rel="%23%ED%8D%BC%EC%8B%A4%EB%A6%AC%ED%85%8C%EC%9D%B4%EC%85%98%EB%9F%AC%EB%8B%9D%ED%8D%BC%EC%8B%A4%EB%A6%AC%ED%85%8C%EC%9D%B4%EC%85%98">#퍼실리테이션러닝퍼실리테이션</span>
#  </div>
#  </div>
#  <!-- list_  리스트 형식일때 보여짐. : 추가된 항목 -->
#  <div class="list_date_place">
#  <div class="wrapping">
#  <span class="date">2019.6.8 (토) 10:00 ~ 2019.6.9 (일) 18:00</span>
#  <span class="place">서울 서초구</span>
#  </div>
#  </div>
#  <!-- ONOFFMIX-3408 모임보기가 리스트 형일때만 보여짐 : 구조변경됨 확인바람 -->
#  <div class="event_state_area">
#  <div class="wrapping">
#  <span class="available"><strong>20</strong>명 신청가능</span>
#  <!-- 추가된 항목 -->
#  <span class="before_closing">마감 <strong class="day">5일전</strong></span>
#  </div>
#  </div>
#  </a>, <a href="/event/182103" target="_blank">
#  <!-- 이미지 -->
#  <div class="event_thumbnail">
#  <div class="end_layer">
#  <p class="end_txt">종료된 모임입니다</p>
#  </div>
#  <img alt="청년들의 몸, 마음 활력을 위한&lt;청춘활력소&gt;" src="https://cfile1.onoffmix.com/images/event/182103/s"/>
#  </div>
#  <div class="event_info_area">
#  <!-- 타이틀 -->
#  <div class="title_area">
#  <h5 class="title ellipsis" title="청년들의 몸, 마음 활력을 위한&lt;청춘활력소&gt;">청년들의 몸, 마음 활력을 위한&lt;청춘활력소&gt;</h5>
#  <!-- 심플 라인일때만 보여짐 -->
#  <!-- <h6 class='sub_title'>서브 타이틀입니다</h6> -->
#  </div>
#  <!-- 정보 -->
#  <div class="event_info">
#  <div class="type_info">
#  <span class="payment_type pay">유료</span>
#  <span class="category_type">교육</span>
#  </div>
#  <div class="date">6.19</div>
#  </div>
#  <!-- 태그 => 리스트 형식일때 보여짐. : 추가된 항목  -->
#  <div class="list_event_tags">
#  <span class="tag" rel="%23%EC%9A%94%EA%B0%80">#요가</span><span class="tag" rel="%23%EB%AC%B4%EC%A4%91%EB%A0%A5%EC%A7%80%EB%8C%80%EB%8C%80%EB%B0%A9%EB%8F%99">#무중력지대대방동</span><span class="tag" rel="%23%EC%B2%AD%EB%85%84%EA%B5%90%EC%9C%A1">#청년교육</span><span class="tag" rel="%23%ED%9E%90%EB%A7%81%ED%94%84%EB%A1%9C%EA%B7%B8%EB%9E%A8">#힐링프로그램</span>
#  </div>
#  </div>
#  <!-- list_  리스트 형식일때 보여짐. : 추가된 항목 -->
#  <div class="list_date_place">
#  <div class="wrapping">
#  <span class="date">2019.6.19 (수) 19:30 ~ 21:30</span>
#  <span class="place">서울 동작구</span>
#  </div>
#  </div>
#  <!-- ONOFFMIX-3408 모임보기가 리스트 형일때만 보여짐 : 구조변경됨 확인바람 -->
#  <div class="event_state_area">
#  <div class="wrapping">
#  <span class="available"><strong>15</strong>명 신청가능</span>
#  <!-- 추가된 항목 -->
#  <span class="before_closing">마감 <strong class="day">2주전</strong></span>
#  </div>
#  </div>
#  </a>, <a href="/event/182097" target="_blank">
#  <!-- 이미지 -->
#  <div class="event_thumbnail">
#  <div class="end_layer">
#  <p class="end_txt">종료된 모임입니다</p>
#  </div>
#  <img alt="＃6월모집＃1:1 지능검사 K-WAIS -4와 K-WISC-4 개별 실습과 수련" src="https://cfile1.onoffmix.com/images/event/182097/s"/>
#  </div>
#  <div class="event_info_area">
#  <!-- 타이틀 -->
#  <div class="title_area">
#  <h5 class="title ellipsis" title="＃6월모집＃1:1 지능검사 K-WAIS -4와 K-WISC-4 개별 실습과 수련">＃6월모집＃1:1 지능검사 K-WAIS -4와 K-WISC-4 개별 실습과 수련</h5>
#  <!-- 심플 라인일때만 보여짐 -->
#  <!-- <h6 class='sub_title'>서브 타이틀입니다</h6> -->
#  </div>
#  <!-- 정보 -->
#  <div class="event_info">
#  <div class="type_info">
#  <span class="payment_type pay">유료</span>
#  <span class="category_type">교육</span>
#  </div>
#  <div class="date">6.7 ~ 6.28</div>
#  </div>
#  <!-- 태그 => 리스트 형식일때 보여짐. : 추가된 항목  -->
#  <div class="list_event_tags">
#  </div>
#  </div>
#  <!-- list_  리스트 형식일때 보여짐. : 추가된 항목 -->
#  <div class="list_date_place">
#  <div class="wrapping">
#  <span class="date">2019.6.7 (금) 10:00 ~ 2019.6.28 (금) 17:00</span>
#  <span class="place">경기 부천시</span>
#  </div>
#  </div>
#  <!-- ONOFFMIX-3408 모임보기가 리스트 형일때만 보여짐 : 구조변경됨 확인바람 -->
#  <div class="event_state_area">
#  <div class="wrapping">
#  <span class="available"><strong>10</strong>명 신청가능</span>
#  <!-- 추가된 항목 -->
#  <span class="before_closing">마감 <strong class="day">3일전</strong></span>
#  </div>
#  </div>
#  </a>, <a href="/event/182095" target="_blank">
#  <!-- 이미지 -->
#  <div class="event_thumbnail">
#  <div class="end_layer">
#  <p class="end_txt">종료된 모임입니다</p>
#  </div>
#  <img alt="[6월오픈] 로샤고급 사례분석 및 해석 중심 워크샵 (3시간)" src="https://cfile1.onoffmix.com/images/event/182095/s"/>
#  </div>
#  <div class="event_info_area">
#  <!-- 타이틀 -->
#  <div class="title_area">
#  <h5 class="title ellipsis" title="[6월오픈] 로샤고급 사례분석 및 해석 중심 워크샵 (3시간)">[6월오픈] 로샤고급 사례분석 및 해석 중심 워크샵 (3시간)</h5>
#  <!-- 심플 라인일때만 보여짐 -->
#  <!-- <h6 class='sub_title'>서브 타이틀입니다</h6> -->
#  </div>
#  <!-- 정보 -->
#  <div class="event_info">
#  <div class="type_info">
#  <span class="payment_type pay">유료</span>
#  <span class="category_type">교육</span>
#  </div>
#  <div class="date">6.22</div>
#  </div>
#  <!-- 태그 => 리스트 형식일때 보여짐. : 추가된 항목  -->
#  <div class="list_event_tags">
#  </div>
#  </div>
#  <!-- list_  리스트 형식일때 보여짐. : 추가된 항목 -->
#  <div class="list_date_place">
#  <div class="wrapping">
#  <span class="date">2019.6.22 (토) 13:00 ~ 16:00</span>
#  <span class="place">경기 부천시</span>
#  </div>
#  </div>
#  <!-- ONOFFMIX-3408 모임보기가 리스트 형일때만 보여짐 : 구조변경됨 확인바람 -->
#  <div class="event_state_area">
#  <div class="wrapping">
#  <span class="available"><strong>10</strong>명 신청가능</span>
#  <!-- 추가된 항목 -->
#  <span class="before_closing">마감 <strong class="day">3주전</strong></span>
#  </div>
#  </div>
#  </a>, <a href="/event/182093" target="_blank">
#  <!-- 이미지 -->
#  <div class="event_thumbnail">
#  <div class="end_layer">
#  <p class="end_txt">종료된 모임입니다</p>
#  </div>
#  <img alt="[6월오픈] K-Bayley-Ⅲ 베일리 영유아 발달검사 워크숍" src="https://cfile1.onoffmix.com/images/event/182093/s"/>
#  </div>
#  <div class="event_info_area">
#  <!-- 타이틀 -->
#  <div class="title_area">
#  <h5 class="title ellipsis" title="[6월오픈] K-Bayley-Ⅲ 베일리 영유아 발달검사 워크숍">[6월오픈] K-Bayley-Ⅲ 베일리 영유아 발달검사 워크숍</h5>
#  <!-- 심플 라인일때만 보여짐 -->
#  <!-- <h6 class='sub_title'>서브 타이틀입니다</h6> -->
#  </div>
#  <!-- 정보 -->
#  <div class="event_info">
#  <div class="type_info">
#  <span class="payment_type pay">유료</span>
#  <span class="category_type">교육</span>
#  </div>
#  <div class="date">6.21</div>
#  </div>
#  <!-- 태그 => 리스트 형식일때 보여짐. : 추가된 항목  -->
#  <div class="list_event_tags">
#  </div>
#  </div>
#  <!-- list_  리스트 형식일때 보여짐. : 추가된 항목 -->
#  <div class="list_date_place">
#  <div class="wrapping">
#  <span class="date">2019.6.21 (금) 18:00 ~ 21:00</span>
#  <span class="place">경기 부천시</span>
#  </div>
#  </div>
#  <!-- ONOFFMIX-3408 모임보기가 리스트 형일때만 보여짐 : 구조변경됨 확인바람 -->
#  <div class="event_state_area">
#  <div class="wrapping">
#  <span class="available"><strong>10</strong>명 신청가능</span>
#  <!-- 추가된 항목 -->
#  <span class="before_closing">마감 <strong class="day">3주전</strong></span>
#  </div>
#  </div>
#  </a>, <a href="/event/182077" target="_blank">
#  <!-- 이미지 -->
#  <div class="event_thumbnail">
#  <div class="end_layer">
#  <p class="end_txt">종료된 모임입니다</p>
#  </div>
#  <img alt="인스타그램 4시간 마스터(6/14)" src="https://cfile1.onoffmix.com/images/event/182077/s"/>
#  </div>
#  <div class="event_info_area">
#  <!-- 타이틀 -->
#  <div class="title_area">
#  <h5 class="title ellipsis" title="인스타그램 4시간 마스터(6/14)">인스타그램 4시간 마스터(6/14)</h5>
#  <!-- 심플 라인일때만 보여짐 -->
#  <!-- <h6 class='sub_title'>서브 타이틀입니다</h6> -->
#  </div>
#  <!-- 정보 -->
#  <div class="event_info">
#  <div class="type_info">
#  <span class="payment_type pay">유료</span>
#  <span class="category_type">교육</span>
#  </div>
#  <div class="date">6.14</div>
#  </div>
#  <!-- 태그 => 리스트 형식일때 보여짐. : 추가된 항목  -->
#  <div class="list_event_tags">
#  </div>
#  </div>
#  <!-- list_  리스트 형식일때 보여짐. : 추가된 항목 -->
#  <div class="list_date_place">
#  <div class="wrapping">
#  <span class="date">2019.6.14 (금) 18:00 ~ 22:00</span>
#  <span class="place">서울 강남구</span>
#  </div>
#  </div>
#  <!-- ONOFFMIX-3408 모임보기가 리스트 형일때만 보여짐 : 구조변경됨 확인바람 -->
#  <div class="event_state_area">
#  <div class="wrapping">
#  <span class="available"><strong>6</strong>명 신청가능</span>
#  <!-- 추가된 항목 -->
#  <span class="before_closing">마감 <strong class="day">1주전</strong></span>
#  </div>
#  </div>
#  </a>, <a href="/event/182076" target="_blank">
#  <!-- 이미지 -->
#  <div class="event_thumbnail">
#  <div class="end_layer">
#  <p class="end_txt">종료된 모임입니다</p>
#  </div>
#  <img alt="워드프레스 쇼핑몰 우커머스 기초 1:1 개인수업" src="https://cfile1.onoffmix.com/images/event/182076/s"/>
#  </div>
#  <div class="event_info_area">
#  <!-- 타이틀 -->
#  <div class="title_area">
#  <h5 class="title ellipsis" title="워드프레스 쇼핑몰 우커머스 기초 1:1 개인수업">워드프레스 쇼핑몰 우커머스 기초 1:1 개인수업</h5>
#  <!-- 심플 라인일때만 보여짐 -->
#  <!-- <h6 class='sub_title'>서브 타이틀입니다</h6> -->
#  </div>
#  <!-- 정보 -->
#  <div class="event_info">
#  <div class="type_info">
#  <span class="payment_type pay">유료</span>
#  <span class="category_type">교육</span>
#  </div>
#  <div class="date">6.7 ~ 7.5</div>
#  </div>
#  <!-- 태그 => 리스트 형식일때 보여짐. : 추가된 항목  -->
#  <div class="list_event_tags">
#  <span class="tag" rel="%23%EC%B7%A8%EC%97%85">#취업</span><span class="tag" rel="%23%EA%B5%90%EC%9C%A1">#교육</span><span class="tag" rel="%23%ED%99%88%ED%8E%98%EC%9D%B4%EC%A7%80">#홈페이지</span><span class="tag" rel="%23%EC%9B%8C%EB%93%9C%ED%94%84%EB%A0%88%EC%8A%A4">#워드프레스</span><span class="tag" rel="%23%EC%B0%BD%EC%97%85%EC%A7%80%EC%9B%90%EA%B8%88">#창업지원금</span>
#  </div>
#  </div>
#  <!-- list_  리스트 형식일때 보여짐. : 추가된 항목 -->
#  <div class="list_date_place">
#  <div class="wrapping">
#  <span class="date">2019.6.7 (금) 19:00 ~ 2019.7.5 (금) 21:00</span>
#  <span class="place">서울 금천구</span>
#  </div>
#  </div>
#  <!-- ONOFFMIX-3408 모임보기가 리스트 형일때만 보여짐 : 구조변경됨 확인바람 -->
#  <div class="event_state_area">
#  <div class="wrapping">
#  <span class="available"><strong>1</strong>명 신청가능</span>
#  <!-- 추가된 항목 -->
#  <span class="before_closing">마감 <strong class="day">4일전</strong></span>
#  </div>
#  </div>
#  </a>, <a href="/event/182075" target="_blank">
#  <!-- 이미지 -->
#  <div class="event_thumbnail">
#  <div class="end_layer">
#  <p class="end_txt">종료된 모임입니다</p>
#  </div>
#  <img alt="네이버 블로그 5시간만에 왕초보탈출(6/14)" src="https://cfile1.onoffmix.com/images/event/182075/s"/>
#  </div>
#  <div class="event_info_area">
#  <!-- 타이틀 -->
#  <div class="title_area">
#  <h5 class="title ellipsis" title="네이버 블로그 5시간만에 왕초보탈출(6/14)">네이버 블로그 5시간만에 왕초보탈출(6/14)</h5>
#  <!-- 심플 라인일때만 보여짐 -->
#  <!-- <h6 class='sub_title'>서브 타이틀입니다</h6> -->
#  </div>
#  <!-- 정보 -->
#  <div class="event_info">
#  <div class="type_info">
#  <span class="payment_type pay">유료</span>
#  <span class="category_type">교육</span>
#  </div>
#  <div class="date">6.14</div>
#  </div>
#  <!-- 태그 => 리스트 형식일때 보여짐. : 추가된 항목  -->
#  <div class="list_event_tags">
#  </div>
#  </div>
#  <!-- list_  리스트 형식일때 보여짐. : 추가된 항목 -->
#  <div class="list_date_place">
#  <div class="wrapping">
#  <span class="date">2019.6.14 (금) 13:00 ~ 18:00</span>
#  <span class="place">서울 강남구</span>
#  </div>
#  </div>
#  <!-- ONOFFMIX-3408 모임보기가 리스트 형일때만 보여짐 : 구조변경됨 확인바람 -->
#  <div class="event_state_area">
#  <div class="wrapping">
#  <span class="available"><strong>6</strong>명 신청가능</span>
#  <!-- 추가된 항목 -->
#  <span class="before_closing">마감 <strong class="day">1주전</strong></span>
#  </div>
#  </div>
#  </a>, <a href="/event/182074" target="_blank">
#  <!-- 이미지 -->
#  <div class="event_thumbnail">
#  <div class="end_layer">
#  <p class="end_txt">종료된 모임입니다</p>
#  </div>
#  <img alt="인스타그램 마케팅과 쇼핑태그 2시간 완전정복(6/14)" src="https://cfile1.onoffmix.com/images/event/182074/s"/>
#  </div>
#  <div class="event_info_area">
#  <!-- 타이틀 -->
#  <div class="title_area">
#  <h5 class="title ellipsis" title="인스타그램 마케팅과 쇼핑태그 2시간 완전정복(6/14)">인스타그램 마케팅과 쇼핑태그 2시간 완전정복(6/14)</h5>
#  <!-- 심플 라인일때만 보여짐 -->
#  <!-- <h6 class='sub_title'>서브 타이틀입니다</h6> -->
#  </div>
#  <!-- 정보 -->
#  <div class="event_info">
#  <div class="type_info">
#  <span class="payment_type pay">유료</span>
#  <span class="category_type">교육</span>
#  </div>
#  <div class="date">6.14</div>
#  </div>
#  <!-- 태그 => 리스트 형식일때 보여짐. : 추가된 항목  -->
#  <div class="list_event_tags">
#  <span class="tag" rel="%23%ED%95%B4%EC%89%AC%ED%83%9C%EA%B7%B8">#해쉬태그</span><span class="tag" rel="%23SNS">#SNS</span><span class="tag" rel="%23%EC%9D%B8%EC%8A%A4%ED%83%80%EA%B7%B8%EB%9E%A8%EB%A7%88%EC%BC%80%ED%8C%85">#인스타그램마케팅</span><span class="tag" rel="%23%EC%9D%B8%EC%8A%A4%ED%83%80%EA%B7%B8%EB%9E%A8">#인스타그램</span>
#  </div>
#  </div>
#  <!-- list_  리스트 형식일때 보여짐. : 추가된 항목 -->
#  <div class="list_date_place">
#  <div class="wrapping">
#  <span class="date">2019.6.14 (금) 10:00 ~ 12:00</span>
#  <span class="place">서울 강남구</span>
#  </div>
#  </div>
#  <!-- ONOFFMIX-3408 모임보기가 리스트 형일때만 보여짐 : 구조변경됨 확인바람 -->
#  <div class="event_state_area">
#  <div class="wrapping">
#  <span class="available"><strong>3</strong>명 신청가능</span>
#  <!-- 추가된 항목 -->
#  <span class="before_closing">마감 <strong class="day">1주전</strong></span>
#  </div>
#  </div>
#  </a>, <a href="/event/182072" target="_blank">
#  <!-- 이미지 -->
#  <div class="event_thumbnail">
#  <div class="end_layer">
#  <p class="end_txt">종료된 모임입니다</p>
#  </div>
#  <img alt="워드프레스 프리미엄 중급과정 Customizing(6/14)" src="https://cfile1.onoffmix.com/images/event/182072/s"/>
#  </div>
#  <div class="event_info_area">
#  <!-- 타이틀 -->
#  <div class="title_area">
#  <h5 class="title ellipsis" title="워드프레스 프리미엄 중급과정 Customizing(6/14)">워드프레스 프리미엄 중급과정 Customizing(6/14)</h5>
#  <!-- 심플 라인일때만 보여짐 -->
#  <!-- <h6 class='sub_title'>서브 타이틀입니다</h6> -->
#  </div>
#  <!-- 정보 -->
#  <div class="event_info">
#  <div class="type_info">
#  <span class="payment_type pay">유료</span>
#  <span class="category_type">교육</span>
#  </div>
#  <div class="date">6.14</div>
#  </div>
#  <!-- 태그 => 리스트 형식일때 보여짐. : 추가된 항목  -->
#  <div class="list_event_tags">
#  <span class="tag" rel="%23%ED%99%88%ED%8E%98%EC%9D%B4%EC%A7%80">#홈페이지</span><span class="tag" rel="%23%EC%9B%8C%EB%93%9C%ED%94%84%EB%A0%88%EC%8A%A4">#워드프레스</span><span class="tag" rel="%23wordpress">#wordpress</span><span class="tag" rel="%23%ED%94%84%EB%A6%AC%EB%AF%B8%EC%97%84">#프리미엄</span><span class="tag" rel="%23%EC%BB%A4%EC%8A%A4%ED%84%B0%EB%A7%88%EC%9D%B4%EC%A7%95">#커스터마이징</span>
#  </div>
#  </div>
#  <!-- list_  리스트 형식일때 보여짐. : 추가된 항목 -->
#  <div class="list_date_place">
#  <div class="wrapping">
#  <span class="date">2019.6.14 (금) 14:00 ~ 22:00</span>
#  <span class="place">서울 강남구</span>
#  </div>
#  </div>
#  <!-- ONOFFMIX-3408 모임보기가 리스트 형일때만 보여짐 : 구조변경됨 확인바람 -->
#  <div class="event_state_area">
#  <div class="wrapping">
#  <span class="available"><strong>6</strong>명 신청가능</span>
#  <!-- 추가된 항목 -->
#  <span class="before_closing">마감 <strong class="day">1주전</strong></span>
#  </div>
#  </div>
#  </a>, <a href="/event/182071" target="_blank">
#  <!-- 이미지 -->
#  <div class="event_thumbnail">
#  <div class="end_layer">
#  <p class="end_txt">종료된 모임입니다</p>
#  </div>
#  <img alt="워드프레스 4시간 속성 마스터과정(6/14)" src="https://cfile1.onoffmix.com/images/event/182071/s"/>
#  </div>
#  <div class="event_info_area">
#  <!-- 타이틀 -->
#  <div class="title_area">
#  <h5 class="title ellipsis" title="워드프레스 4시간 속성 마스터과정(6/14)">워드프레스 4시간 속성 마스터과정(6/14)</h5>
#  <!-- 심플 라인일때만 보여짐 -->
#  <!-- <h6 class='sub_title'>서브 타이틀입니다</h6> -->
#  </div>
#  <!-- 정보 -->
#  <div class="event_info">
#  <div class="type_info">
#  <span class="payment_type pay">유료</span>
#  <span class="category_type">교육</span>
#  </div>
#  <div class="date">6.14</div>
#  </div>
#  <!-- 태그 => 리스트 형식일때 보여짐. : 추가된 항목  -->
#  <div class="list_event_tags">
#  <span class="tag" rel="%23%EA%B5%90%EC%9C%A1">#교육</span><span class="tag" rel="%23%ED%99%88%ED%8E%98%EC%9D%B4%EC%A7%80">#홈페이지</span><span class="tag" rel="%23%EC%9B%8C%EB%93%9C%ED%94%84%EB%A0%88%EC%8A%A4">#워드프레스</span><span class="tag" rel="%23wordpress">#wordpress</span><span class="tag" rel="%23%EB%B0%98%EC%9D%91%ED%98%95%ED%99%88%ED%8E%98%EC%9D%B4%EC%A7%80">#반응형홈페이지</span>
#  </div>
#  </div>
#  <!-- list_  리스트 형식일때 보여짐. : 추가된 항목 -->
#  <div class="list_date_place">
#  <div class="wrapping">
#  <span class="date">2019.6.14 (금) 9:00 ~ 18:00</span>
#  <span class="place">서울 강남구</span>
#  </div>
#  </div>
#  <!-- ONOFFMIX-3408 모임보기가 리스트 형일때만 보여짐 : 구조변경됨 확인바람 -->
#  <div class="event_state_area">
#  <div class="wrapping">
#  <span class="available"><strong>6</strong>명 신청가능</span>
#  <!-- 추가된 항목 -->
#  <span class="before_closing">마감 <strong class="day">1주전</strong></span>
#  </div>
#  </div>
#  </a>, <a href="/event/182070" target="_blank">
#  <!-- 이미지 -->
#  <div class="event_thumbnail">
#  <div class="end_layer">
#  <p class="end_txt">종료된 모임입니다</p>
#  </div>
#  <img alt="워드프레스 기초부터 쇼핑몰까지 5시간 완성과정(6/13)" src="https://cfile1.onoffmix.com/images/event/182070/s"/>
#  </div>
#  <div class="event_info_area">
#  <!-- 타이틀 -->
#  <div class="title_area">
#  <h5 class="title ellipsis" title="워드프레스 기초부터 쇼핑몰까지 5시간 완성과정(6/13)">워드프레스 기초부터 쇼핑몰까지 5시간 완성과정(6/13)</h5>
#  <!-- 심플 라인일때만 보여짐 -->
#  <!-- <h6 class='sub_title'>서브 타이틀입니다</h6> -->
#  </div>
#  <!-- 정보 -->
#  <div class="event_info">
#  <div class="type_info">
#  <span class="payment_type pay">유료</span>
#  <span class="category_type">교육</span>
#  </div>
#  <div class="date">6.13</div>
#  </div>
#  <!-- 태그 => 리스트 형식일때 보여짐. : 추가된 항목  -->
#  <div class="list_event_tags">
#  </div>
#  </div>
#  <!-- list_  리스트 형식일때 보여짐. : 추가된 항목 -->
#  <div class="list_date_place">
#  <div class="wrapping">
#  <span class="date">2019.6.13 (목) 9:00 ~ 22:00</span>
#  <span class="place">서울 강남구</span>
#  </div>
#  </div>
#  <!-- ONOFFMIX-3408 모임보기가 리스트 형일때만 보여짐 : 구조변경됨 확인바람 -->
#  <div class="event_state_area">
#  <div class="wrapping">
#  <span class="available"><strong>6</strong>명 신청가능</span>
#  <!-- 추가된 항목 -->
#  <span class="before_closing">마감 <strong class="day">1주전</strong></span>
#  </div>
#  </div>
#  </a>, <a href="/event/182069" target="_blank">
#  <!-- 이미지 -->
#  <div class="event_thumbnail">
#  <div class="end_layer">
#  <p class="end_txt">종료된 모임입니다</p>
#  </div>
#  <img alt="인스타그램 마케팅과 쇼핑태그 2시간 완전정복(6/13)" src="https://cfile1.onoffmix.com/images/event/182069/s"/>
#  </div>
#  <div class="event_info_area">
#  <!-- 타이틀 -->
#  <div class="title_area">
#  <h5 class="title ellipsis" title="인스타그램 마케팅과 쇼핑태그 2시간 완전정복(6/13)">인스타그램 마케팅과 쇼핑태그 2시간 완전정복(6/13)</h5>
#  <!-- 심플 라인일때만 보여짐 -->
#  <!-- <h6 class='sub_title'>서브 타이틀입니다</h6> -->
#  </div>
#  <!-- 정보 -->
#  <div class="event_info">
#  <div class="type_info">
#  <span class="payment_type pay">유료</span>
#  <span class="category_type">교육</span>
#  </div>
#  <div class="date">6.13</div>
#  </div>
#  <!-- 태그 => 리스트 형식일때 보여짐. : 추가된 항목  -->
#  <div class="list_event_tags">
#  <span class="tag" rel="%23%ED%95%B4%EC%89%AC%ED%83%9C%EA%B7%B8">#해쉬태그</span><span class="tag" rel="%23SNS">#SNS</span><span class="tag" rel="%23%EC%9D%B8%EC%8A%A4%ED%83%80%EA%B7%B8%EB%9E%A8%EB%A7%88%EC%BC%80%ED%8C%85">#인스타그램마케팅</span><span class="tag" rel="%23%EC%9D%B8%EC%8A%A4%ED%83%80%EA%B7%B8%EB%9E%A8">#인스타그램</span>
#  </div>
#  </div>
#  <!-- list_  리스트 형식일때 보여짐. : 추가된 항목 -->
#  <div class="list_date_place">
#  <div class="wrapping">
#  <span class="date">2019.6.13 (목) 14:00 ~ 22:00</span>
#  <span class="place">서울 강남구</span>
#  </div>
#  </div>
#  <!-- ONOFFMIX-3408 모임보기가 리스트 형일때만 보여짐 : 구조변경됨 확인바람 -->
#  <div class="event_state_area">
#  <div class="wrapping">
#  <span class="available"><strong>6</strong>명 신청가능</span>
#  <!-- 추가된 항목 -->
#  <span class="before_closing">마감 <strong class="day">1주전</strong></span>
#  </div>
#  </div>
#  </a>, <a href="/event/182068" target="_blank">
#  <!-- 이미지 -->
#  <div class="event_thumbnail">
#  <div class="end_layer">
#  <p class="end_txt">종료된 모임입니다</p>
#  </div>
#  <img alt="인스타그램 마케팅 성공법, 2시간 완전정복(6/13)" src="https://cfile1.onoffmix.com/images/event/182068/s"/>
#  </div>
#  <div class="event_info_area">
#  <!-- 타이틀 -->
#  <div class="title_area">
#  <h5 class="title ellipsis" title="인스타그램 마케팅 성공법, 2시간 완전정복(6/13)">인스타그램 마케팅 성공법, 2시간 완전정복(6/13)</h5>
#  <!-- 심플 라인일때만 보여짐 -->
#  <!-- <h6 class='sub_title'>서브 타이틀입니다</h6> -->
#  </div>
#  <!-- 정보 -->
#  <div class="event_info">
#  <div class="type_info">
#  <span class="payment_type pay">유료</span>
#  <span class="category_type">교육</span>
#  </div>
#  <div class="date">6.13</div>
#  </div>
#  <!-- 태그 => 리스트 형식일때 보여짐. : 추가된 항목  -->
#  <div class="list_event_tags">
#  <span class="tag" rel="%23%ED%95%B4%EC%89%AC%ED%83%9C%EA%B7%B8">#해쉬태그</span><span class="tag" rel="%23SNS">#SNS</span><span class="tag" rel="%23%EC%9D%B8%EC%8A%A4%ED%83%80%EA%B7%B8%EB%9E%A8%EB%A7%88%EC%BC%80%ED%8C%85">#인스타그램마케팅</span><span class="tag" rel="%23%EC%9D%B8%EC%8A%A4%ED%83%80%EA%B7%B8%EB%9E%A8">#인스타그램</span>
#  </div>
#  </div>
#  <!-- list_  리스트 형식일때 보여짐. : 추가된 항목 -->
#  <div class="list_date_place">
#  <div class="wrapping">
#  <span class="date">2019.6.13 (목) 10:00 ~ 12:00</span>
#  <span class="place">서울 강남구</span>
#  </div>
#  </div>
#  <!-- ONOFFMIX-3408 모임보기가 리스트 형일때만 보여짐 : 구조변경됨 확인바람 -->
#  <div class="event_state_area">
#  <div class="wrapping">
#  <span class="available"><strong>6</strong>명 신청가능</span>
#  <!-- 추가된 항목 -->
#  <span class="before_closing">마감 <strong class="day">1주전</strong></span>
#  </div>
#  </div>
#  </a>, <a href="/event/182067" target="_blank">
#  <!-- 이미지 -->
#  <div class="event_thumbnail">
#  <div class="end_layer">
#  <p class="end_txt">종료된 모임입니다</p>
#  </div>
#  <img alt="워드프레스 5시간 속성 마스터 과정(6/13)" src="https://cfile1.onoffmix.com/images/event/182067/s"/>
#  </div>
#  <div class="event_info_area">
#  <!-- 타이틀 -->
#  <div class="title_area">
#  <h5 class="title ellipsis" title="워드프레스 5시간 속성 마스터 과정(6/13)">워드프레스 5시간 속성 마스터 과정(6/13)</h5>
#  <!-- 심플 라인일때만 보여짐 -->
#  <!-- <h6 class='sub_title'>서브 타이틀입니다</h6> -->
#  </div>
#  <!-- 정보 -->
#  <div class="event_info">
#  <div class="type_info">
#  <span class="payment_type pay">유료</span>
#  <span class="category_type">교육</span>
#  </div>
#  <div class="date">6.13</div>
#  </div>
#  <!-- 태그 => 리스트 형식일때 보여짐. : 추가된 항목  -->
#  <div class="list_event_tags">
#  </div>
#  </div>
#  <!-- list_  리스트 형식일때 보여짐. : 추가된 항목 -->
#  <div class="list_date_place">
#  <div class="wrapping">
#  <span class="date">2019.6.13 (목) 13:00 ~ 22:00</span>
#  <span class="place">서울 강남구</span>
#  </div>
#  </div>
#  <!-- ONOFFMIX-3408 모임보기가 리스트 형일때만 보여짐 : 구조변경됨 확인바람 -->
#  <div class="event_state_area">
#  <div class="wrapping">
#  <span class="available"><strong>6</strong>명 신청가능</span>
#  <!-- 추가된 항목 -->
#  <span class="before_closing">마감 <strong class="day">1주전</strong></span>
#  </div>
#  </div>
#  </a>, <a href="/event/182066" target="_blank">
#  <!-- 이미지 -->
#  <div class="event_thumbnail">
#  <div class="end_layer">
#  <p class="end_txt">종료된 모임입니다</p>
#  </div>
#  <img alt="워드프레스 3시간 속성 마스터하기(6/13)" src="https://cfile1.onoffmix.com/images/event/182066/s"/>
#  </div>
#  <div class="event_info_area">
#  <!-- 타이틀 -->
#  <div class="title_area">
#  <h5 class="title ellipsis" title="워드프레스 3시간 속성 마스터하기(6/13)">워드프레스 3시간 속성 마스터하기(6/13)</h5>
#  <!-- 심플 라인일때만 보여짐 -->
#  <!-- <h6 class='sub_title'>서브 타이틀입니다</h6> -->
#  </div>
#  <!-- 정보 -->
#  <div class="event_info">
#  <div class="type_info">
#  <span class="payment_type pay">유료</span>
#  <span class="category_type">교육</span>
#  </div>
#  <div class="date">6.13</div>
#  </div>
#  <!-- 태그 => 리스트 형식일때 보여짐. : 추가된 항목  -->
#  <div class="list_event_tags">
#  <span class="tag" rel="%23%EC%87%BC%ED%95%91%EB%AA%B0%EC%A0%9C%EC%9E%91">#쇼핑몰제작</span><span class="tag" rel="%23%ED%99%88%ED%8E%98%EC%9D%B4%EC%A7%80">#홈페이지</span><span class="tag" rel="%23%EC%9B%8C%EB%93%9C%ED%94%84%EB%A0%88%EC%8A%A4">#워드프레스</span><span class="tag" rel="%23wordpress">#wordpress</span>
#  </div>
#  </div>
#  <!-- list_  리스트 형식일때 보여짐. : 추가된 항목 -->
#  <div class="list_date_place">
#  <div class="wrapping">
#  <span class="date">2019.6.13 (목) 10:00 ~ 22:00</span>
#  <span class="place">서울 강남구</span>
#  </div>
#  </div>
#  <!-- ONOFFMIX-3408 모임보기가 리스트 형일때만 보여짐 : 구조변경됨 확인바람 -->
#  <div class="event_state_area">
#  <div class="wrapping">
#  <span class="available"><strong>6</strong>명 신청가능</span>
#  <!-- 추가된 항목 -->
#  <span class="before_closing">마감 <strong class="day">1주전</strong></span>
#  </div>
#  </div>
#  </a>, <a href="/event/182059" target="_blank">
#  <!-- 이미지 -->
#  <div class="event_thumbnail">
#  <div class="end_layer">
#  <p class="end_txt">종료된 모임입니다</p>
#  </div>
#  <img alt="3D 프린터 운용기능사 실기 대비 과정" src="https://cfile1.onoffmix.com/images/event/182059/s"/>
#  </div>
#  <div class="event_info_area">
#  <!-- 타이틀 -->
#  <div class="title_area">
#  <h5 class="title ellipsis" title="3D 프린터 운용기능사 실기 대비 과정">3D 프린터 운용기능사 실기 대비 과정</h5>
#  <!-- 심플 라인일때만 보여짐 -->
#  <!-- <h6 class='sub_title'>서브 타이틀입니다</h6> -->
#  </div>
#  <!-- 정보 -->
#  <div class="event_info">
#  <div class="type_info">
#  <span class="payment_type pay">유료</span>
#  <span class="category_type">교육</span>
#  </div>
#  <div class="date">6.23</div>
#  </div>
#  <!-- 태그 => 리스트 형식일때 보여짐. : 추가된 항목  -->
#  <div class="list_event_tags">
#  <span class="tag" rel="%233d%ED%94%84%EB%A6%B0%ED%84%B0">#3d프린터</span><span class="tag" rel="%23%EA%B5%AD%EA%B0%80%EA%B3%B5%EC%9D%B8%EC%9E%90%EA%B2%A9%EC%A6%9D">#국가공인자격증</span><span class="tag" rel="%23%EC%8B%A4%EA%B8%B0">#실기</span><span class="tag" rel="%233D%ED%94%84%EB%A6%B0%ED%84%B0%EC%9A%B4%EC%9A%A9%EA%B8%B0%EB%8A%A5%EC%82%AC">#3D프린터운용기능사</span>
#  </div>
#  </div>
#  <!-- list_  리스트 형식일때 보여짐. : 추가된 항목 -->
#  <div class="list_date_place">
#  <div class="wrapping">
#  <span class="date">2019.6.23 (일) 10:00 ~ 17:00</span>
#  <span class="place">경기 안산시</span>
#  </div>
#  </div>
#  <!-- ONOFFMIX-3408 모임보기가 리스트 형일때만 보여짐 : 구조변경됨 확인바람 -->
#  <div class="event_state_area">
#  <div class="wrapping">
#  <span class="available"><strong>30</strong>명 신청가능</span>
#  <!-- 추가된 항목 -->
#  <span class="before_closing">마감 <strong class="day">3주전</strong></span>
#  </div>
#  </div>
#  </a>, <a href="/event/182051" target="_blank">
#  <!-- 이미지 -->
#  <div class="event_thumbnail">
#  <div class="end_layer">
#  <p class="end_txt">종료된 모임입니다</p>
#  </div>
#  <img alt="두뇌 회전을 빠르게 &amp; 책을 빠르게!포지 속독!" src="https://cfile1.onoffmix.com/images/event/182051/s"/>
#  </div>
#  <div class="event_info_area">
#  <!-- 타이틀 -->
#  <div class="title_area">
#  <h5 class="title ellipsis" title="두뇌 회전을 빠르게 &amp; 책을 빠르게!포지 속독!">두뇌 회전을 빠르게 &amp; 책을 빠르게!포지 속독!</h5>
#  <!-- 심플 라인일때만 보여짐 -->
#  <!-- <h6 class='sub_title'>서브 타이틀입니다</h6> -->
#  </div>
#  <!-- 정보 -->
#  <div class="event_info">
#  <div class="type_info">
#  <span class="payment_type pay">유료</span>
#  <span class="category_type">교육</span>
#  </div>
#  <div class="date">6.9</div>
#  </div>
#  <!-- 태그 => 리스트 형식일때 보여짐. : 추가된 항목  -->
#  <div class="list_event_tags">
#  <span class="tag" rel="%23%EC%BB%A4%EB%AE%A4%EB%8B%88%EC%BC%80%EC%9D%B4%EC%85%98">#커뮤니케이션</span><span class="tag" rel="%23%EC%9E%90%EA%B8%B0%EA%B0%9C%EB%B0%9C">#자기개발</span><span class="tag" rel="%23%EC%B0%BD%EC%9D%98%EB%A0%A5">#창의력</span><span class="tag" rel="%23%EB%8F%85%EC%84%9C">#독서</span><span class="tag" rel="%23%EC%86%8D%EB%8F%85">#속독</span>
#  </div>
#  </div>
#  <!-- list_  리스트 형식일때 보여짐. : 추가된 항목 -->
#  <div class="list_date_place">
#  <div class="wrapping">
#  <span class="date">2019.6.9 (일) 12:00 ~ 13:30</span>
#  <span class="place">서울 마포구</span>
#  </div>
#  </div>
#  <!-- ONOFFMIX-3408 모임보기가 리스트 형일때만 보여짐 : 구조변경됨 확인바람 -->
#  <div class="event_state_area">
#  <div class="wrapping">
#  <span class="available"><strong>2</strong>명 신청가능</span>
#  <!-- 추가된 항목 -->
#  <span class="before_closing">마감 <strong class="day">5일전</strong></span>
#  </div>
#  </div>
#  </a>, <a href="/event/182050" target="_blank">
#  <!-- 이미지 -->
#  <div class="event_thumbnail">
#  <div class="end_layer">
#  <p class="end_txt">종료된 모임입니다</p>
#  </div>
#  <img alt="두뇌 회전을 빠르게 &amp; 책을 빠르게!포지 속독!" src="https://cfile1.onoffmix.com/images/event/182050/s"/>
#  </div>
#  <div class="event_info_area">
#  <!-- 타이틀 -->
#  <div class="title_area">
#  <h5 class="title ellipsis" title="두뇌 회전을 빠르게 &amp; 책을 빠르게!포지 속독!">두뇌 회전을 빠르게 &amp; 책을 빠르게!포지 속독!</h5>
#  <!-- 심플 라인일때만 보여짐 -->
#  <!-- <h6 class='sub_title'>서브 타이틀입니다</h6> -->
#  </div>
#  <!-- 정보 -->
#  <div class="event_info">
#  <div class="type_info">
#  <span class="payment_type pay">유료</span>
#  <span class="category_type">교육</span>
#  </div>
#  <div class="date">6.8</div>
#  </div>
#  <!-- 태그 => 리스트 형식일때 보여짐. : 추가된 항목  -->
#  <div class="list_event_tags">
#  <span class="tag" rel="%23%EC%BB%A4%EB%AE%A4%EB%8B%88%EC%BC%80%EC%9D%B4%EC%85%98">#커뮤니케이션</span><span class="tag" rel="%23%EC%9E%90%EA%B8%B0%EA%B0%9C%EB%B0%9C">#자기개발</span><span class="tag" rel="%23%EC%B0%BD%EC%9D%98%EB%A0%A5">#창의력</span><span class="tag" rel="%23%EB%8F%85%EC%84%9C">#독서</span><span class="tag" rel="%23%EC%86%8D%EB%8F%85">#속독</span>
#  </div>
#  </div>
#  <!-- list_  리스트 형식일때 보여짐. : 추가된 항목 -->
#  <div class="list_date_place">
#  <div class="wrapping">
#  <span class="date">2019.6.8 (토) 18:00 ~ 19:30</span>
#  <span class="place">서울 마포구</span>
#  </div>
#  </div>
#  <!-- ONOFFMIX-3408 모임보기가 리스트 형일때만 보여짐 : 구조변경됨 확인바람 -->
#  <div class="event_state_area">
#  <div class="wrapping">
#  <span class="available"><strong>2</strong>명 신청가능</span>
#  <!-- 추가된 항목 -->
#  <span class="before_closing">마감 <strong class="day">4일전</strong></span>
#  </div>
#  </div>
#  </a>]

# %%
#각 타겟 페이지 URL추출
target_URL = []
for i in selected:
    target_URL.append(i.get("href"))
target_URL
# Out:
# ['/cs/a/44280?url=%2Fevent%2F181448',
#  '/event/182109',
#  '/event/182103',
#  '/event/182097',
#  '/event/182095',
#  '/event/182093',
#  '/event/182077',
#  '/event/182076',
#  '/event/182075',
#  '/event/182074',
#  '/event/182072',
#  '/event/182071',
#  '/event/182070',
#  '/event/182069',
#  '/event/182068',
#  '/event/182067',
#  '/event/182066',
#  '/event/182059',
#  '/event/182051',
#  '/event/182050']

# %%
#광고 페이지 제거 - /cs/를 포함하면 광고
cs = []
for n in target_URL:
    cs.append(n.find("/cs/"))
del target_URL[cs.index(0)]
target_URL
# Out:
# ['/event/175328',
#  '/event/171868',
#  '/event/180514',
#  '/event/179527',
#  '/event/179519',
#  '/event/177790',
#  '/event/179467',
#  '/event/176432',
#  '/event/180926',
#  '/event/176435',
#  '/event/180925',
#  '/event/176431',
#  '/event/179523',
#  '/event/180924',
#  '/event/139684',
#  '/event/176434',
#  '/event/177696',
#  '/event/169065',
#  '/event/177588']

# %%
#타겟 URL지정해서 get
driver.get(base_URL+target_URL[0])

# %%
#get 타겟 페이지
target_html = driver.page_source
target_soup = BeautifulSoup(target_html, 'html.parser')
#target_soup

# %%
#selector들
#모임기간
date_selector = "#content > div.content_wrapping.max_width_area > section.event_summary > div.right_area > ul > li:nth-child(1) > p"
#모임장소
place_selector = "#content > div.content_wrapping.max_width_area > section.event_summary > div.right_area > ul > li:nth-child(2) > p > span"
#모집정원
limitation_selector = '#content > div.content_wrapping.max_width_area > section.event_summary > div.right_area > ul > li:nth-child(3) > p > span.total > span'
#강연자 이름
name_selector ="#hostInfo > li.host_name > a"
#강연자 email
email_selector = "#hostInfo > li.host_mail"
#강연자 전화번호
phone_selector ="#hostInfo > li.host_phone"

# %%
date_selected = target_soup.select(date_selector)
print(date_selected[0].text)

place_selected = target_soup.select(place_selector)
print(place_selected[0].text)


limitation_selected = target_soup.select(limitation_selector)
print(limitation_selected[0].text)

name_selected = target_soup.select(name_selector)
print(name_selected[0].text)

email_selected2 = target_soup.select(email_selector)
print(email_selected2[0].text)

phone_selected = target_soup.select(phone_selector)
print(phone_selected[0].text)
# Out:
# 2019.7.19 (금) 19:30 ~ 21:30
# [논현역 7호선]서울특별시 강남구 학동로 102 논현역 상세위치는 확정자 분들께만 공지합니다.
# 10
# 강전사
# fmjeff@naver.com
# 010-4046-5646
